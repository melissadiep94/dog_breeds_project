# %%
import pandas as pd
from sqlalchemy import create_engine
import json
import os

# %%
filepath = os.path.join("Resources", "dogs.json")
with open(filepath) as jsonfile:
    video_json = json.load(jsonfile)

# %%
df = pd.DataFrame(video_json['breeds'])

# %%
df
df.rename(columns={'name':'breed_name', 
                   'kidFriendly': 'kid_friendly', 
                   'dogFriendly': 'dog_friendy', 
                   'lowShedding': 'low_shedding',
                   'easyToGroom': 'easy_to_groom', 
                   'highEnergy': 'high_energy', 
                   'goodHealth': 'good_health', 
                   'lowBarking': 'low_barking', 
                   'easyToTrain': 'easy_to_train', 
                   'toleratesHot': 'tolerates_hot',
                   'toleratesCold': 'tolerates_cold'}, inplace=True)

pd.set_option('precision', 0)

# %%
df
# Out:
#                               id                   breed_name  size  \
# 0                  affenpinscher                Affenpinscher     1
# 1                   afghan-hound                 Afghan Hound     4
# 2               airedale-terrier             Airedale Terrier     3
# 3                          akita                        Akita     4
# 4               alaskan-malamute             Alaskan Malamute     4
# ..                           ...                          ...   ...
# 194                      whippet                      Whippet     3
# 195  wirehaired-pointing-griffon  Wirehaired Pointing Griffon     3
# 196                xoloitzuintli               Xoloitzcuintli     3
# 197                     yorkipoo                     Yorkipoo     1
# 198            yorkshire-terrier            Yorkshire Terrier     1
#
#      kid_friendly  dog_friendy  low_shedding  easy_to_groom  high_energy  \
# 0               1            1             5              3            4
# ...

# %%
# Out:
# <bound method Index.format of Index(['id', 'breed_name', 'size', 'kid_friendly', 'dog_friendy',
#        'low_shedding', 'easy_to_groom', 'high_energy', 'good_health',
#        'low_barking', 'intelligence', 'easy_to_train', 'tolerates_hot',
#        'tolerates_cold'],
#       dtype='object')>
